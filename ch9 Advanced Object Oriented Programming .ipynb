# %% [markdown]
# # Polymorphism

# %% [markdown]
# Method-1 : Method Overriding

# %%
def add(a,b):
    print(a+b)

# %%
def add(a,b,c):
    print(a+b+c)

# %%
#add(1,2)#TypeError: add() missing 1 required positional argument: 'c'

# %%
add(1,2,3)
# Out:
# 6

# %% [markdown]
# Method-2 : Operator Overloading

# %%
 class Point:
        def __init__(self, x, y):
            self.x = x
            self.y = y
        def __str__(self):
            return 'x=' + str(self.x) + ' y=' + str(self.y)
        def __add__(self, other):
            x = self.x + other.x
            y = self.y + other.y
            return Point(x, y)
        def __sub__(self, other):
            x = self.x - other.x
            y = self.y - other.y
            return Point(x, y)
        def __mul__(self, other):
            x = self.x * other.x
            y = self.y * other.y
            return Point(x, y)
        def __truediv__(self , other):
            x = self.x / other.x
            y = self.y / other.y
            return Point(x, y)
        def __floordiv__(self , other):
            x = self.x // other.x
            y = self.y // other.y
            return Point(x, y)
        def __mod__(self , other):
            x = self.x % other.x
            y = self.y % other.y
            return Point(x, y)
        def __pow__(self , other):
            x = self.x ** other.x
            y = self.y ** other.y
            return Point(x, y)
        def __lt__(self , other):
            if self.x < other.x:
                if self.y < other.y:
                    return True
            return False
        def __gt__(self , other):
            if self.x > other.x:
                if self.y > other.y:
                    return True
            return False
        def __ge__(self , other):
            if self.x >= other.x:
                if self.y >= other.y:
                    return True
            return False
        def __le__(self , other):
            if self.x <= other.x:
                if self.y <= other.y:
                    return True
            return False
        def __ne__(self , other):
            if self.x != other.x:
                if self.y != other.y:
                    return True
            return False
        def __eq__(self , other):
            if self.x == other.x:
                if self.y == other.y:
                    return True
            return False

# %%
p1=Point(6,31)
p2=Point(3,4)

# %%
print(p1+p2)
print(p1-p2)
print(p1*p2)
print(p1/p2)
print(p1//p2)
print(p1%p2)
print(p1**p2)
print(p1<p2)
print(p1>p2)
print(p1==p2)
print(p1<=p2)
print(p1>=p2)
# Out:
# x=9 y=35
# x=3 y=27
# x=18 y=124
# x=2.0 y=7.75
# x=2 y=7
# x=0 y=3
# x=216 y=923521
# False
# True
# False
# False
# True

# %% [markdown]
# # Inheritance

# %% [markdown]
# 1.Single Inheritance

# %%
class Parent:
    def fun1(self):
        print("Hello Parent")
class Child(Parent):
    def fun2(self):
        print("Hello Child")
# Out:
# Hello Parent
# Hello Child

# %%
p1=Parent()
p1.fun1()
#p1.fun2()#AttributeError: 'Parent' object has no attribute 'fun2'
# Out:
# Hello Parent

# %%
c1=Child()
c1.fun1()
c1.fun2()
# Out:
# Hello Parent
# Hello Child

# %% [markdown]
# 2. Multiple Inheritance

# %%
class Parent1:
    def fun1(self):
        print("Hello Parent 1")
class Parent2:
    def fun2(self):
        print("Hello Parent 2")
        
class Child(Parent1,Parent2):
    def fun3(self):
        print("Hello Child")

# %%
c2=Child()
c2.fun1()
c2.fun2()
c2.fun3()
# Out:
# Hello Parent 1
# Hello Parent 2
# Hello Child

# %% [markdown]
# 3.Multilevel Inheritance

# %%
class GrandParent:
    def fun4(self):
        print("Hello Grand Parent")
class Parent(GrandParent):
    def fun5(self):
        print("Hello Parent")
        
class Child(Parent):
    def fun6(self):
        print("Hello Child")

# %%
c3=Child()
c3.fun4()
c3.fun5()
c3.fun6()
# Out:
# Hello Grand Parent
# Hello Parent
# Hello Child

# %% [markdown]
# 4.Hierarchical Inheritance

# %%
class Parent:
    def fun1(self):
        print("Hello Parent")
class Child1(Parent):
    def fun2(self):
        print("Hello Child 1")
        
class Child2(Parent):
    def fun3(self):
        print("Hello Child 2")

# %%
c5=Child1()
c5.fun2()
c5.fun1()
c6=Child2()
c6.fun3()
# Out:
# Hello Child 1
# Hello Parent
# Hello Child 2

# %% [markdown]
# 5.Hybrid Inheritance

# %%
class GrandParent:
    def fun1(self):
        print("Hello Grand Parent")
            
class Parent1(GrandParent):
    def fun2(self):
        print("Hello Parent 1")
        
class Parent2:
    def fun3(self):
        print("Hello Parent 2")
        
class Child(Parent1,Parent2):
    def fun4(self):
        print("Hello Child")

# %%
c=Child()
c.fun1()
c.fun2()
c.fun3()
c.fun4()
# Out:
# Hello Grand Parent
# Hello Parent 1
# Hello Parent 2
# Hello Child

# %% [markdown]
# # MRO:Method Resolution Order

# %%
class A:
    def test(self):
        print("Hello A")
class B(A):
    def test(self):
        print("Hello B")
class C(A):
    def test(self):
        print("Hello C")
class D(B,C):
       pass

# %%
d1=D()
d1.test()
# Out:
# Hello B

# %%
print(D.__mro__)
# Out:
# (<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>)

# %% [markdown]
# Write a program to create a class called Data having “value” as its data member. Overload the (>) and the (<) operator for
# the class. Instantiate the class and compare the objects using _lt_ and _gt_.

# %%
class Data:
    def __init__(self,value):
        self.value=value
    def __lt__(self,other):
        return self.value<other.value
    def __gt__(self,other):
        return self.value>other.value

# %%
d1=Data(10)
d2=Data(20)
print(d1<d2)
print(d1>d2)
# Out:
# True
# False

# %% [markdown]
#  Create a class student with following member attributes: roll no, name, age and total marks. Create suitable methods for
# reading and printing member variables. Write a python program to overload ‘==’ operator to print the details of students
# having same marks.

# %%
class Student:
    def __init__(self,rollno,name,age,total_marks):
        self.rollno=rollno
        self.name=name
        self.age=age
        self.total_marks=total_marks
    def pq(self):
        print(self.rollno,self.name,self.age,self.total_marks)
    def __eq__(self,other):
        return self.total_marks==other.total_marks

# %%
s1=Student(37,"Daksh",19,243.5)
s2=Student(2,"Ahmad",19,243.5)
if s1==s2:
    print("Students having same mark")
    s1.pq()
    s2.pq()
else:
    print("NOT same mark")
# Out:
# Students having same mark
# 37 Daksh 19 243.5
# 2 Ahmad 19 243.5

# %% [markdown]
# The following illustration creates a class called data. If no argument is passed while instantiating the class a false is
# returned, otherwise a true is returned.

# %%
class Data:
    def __init__(self,value=None):
        if value:
            self.value=value
            self.status=True
        else:
            self.status=False
    def __str__(self):
        return f"status={self.status}"

# %%
x=Data(1)
print(x)

z=Data()
print(z)
# Out:
# status=True
# status=False

# %% [markdown]
# # ABC: Abstarct Base Class

# %%
from abc import ABC,abstractmethod

# %%
class Shape(ABC):
    def __init__(self,name):
        self.name=name
    
    @abstractmethod
    def draw(self):
        pass
    
class Circle(Shape):
    def __init__(self):
        super().__init__("circle")
    def draw(self):
        print("drwaing a circle")

class Triangle(Shape):
    def __init__(self):
        super().__init__("triangle")
    def draw(self):
        print("drwaing a triangle")

# %%
c=Circle()
c.draw()

t=Triangle()
t.draw()
# Out:
# drwaing a circle
# drwaing a triangle

# %% [markdown]
# # Write a Python Program to Find the Net Salary of Employee using Inheritance.
#  # Create three Class Employee, Perks, NetSalary. Make an Employee class as an abstract class.
# # Employee class should have methods for following tasks.- To get employee details like employee id, name and salary from user. - To print the Employee details. - return Salary.- An abstract method emp_id.
#  # Perks class should have methods for following tasks.- To calculate DA, HRA, PF. - To print the individual and total of Perks (DA+HRA-PF).
#  # Netsalary class should have methods for following tasks.- Calculate the total Salary after Perks.- Print employee detail also prints DA, HRA, PF and net salary.

# %%
class Emplyoee(ABC):
    def __init__(self,empid,name,basic_salary):
        self.empid=empid
        self.name=name
        self.salary=basic_salary
    def get_details(self):
        self.empid=int(input("Enter Emplyoee ID:"))
        self.name=input("Enter Emplyoee Name:")
        self.basic_salary=int(input("Enter Emplyoee Basic Salary:"))
        
    def display(self):
        print("Emplyoee ID:",self.empid)
        print("Emplyoee Name:",self.name)
        print("Emplyoee Basic Salary:",self.basic_salary)
    def get_salary(self):
        return self.basic_salary
    
    @abstractmethod
    def emp_id(self):
        pass
    
class Perks(Emplyoee):
    def __init__(self):
        super().__init__()
        self.da=0
        self.hra=0
        self.pf=0
            
    def Calculate(self):
        self.da=0.35*self.basic_salary
        self.hra=0.17*self.basic_salary
        self.pf=0.12*self.basic_salary
        
    def emp_id(self):
        return self.id
    
    def display_tax(self):
        print("DA:",self.da)
        print("HRA:",self.hra)
        print("PF:",self.pf)
        print("Total Addition",(self.da+self.hra-self.pf))
        
class NetSalary(Perks):
    def __init__(self):
        self.ts=0
    def cal_net_salary(self):
        self.ts=self.basic_salary+self.hra-self.pf
    def display1(self):
        self.display()
        self.display_tax()
        print("Total salary=",self.ts)

# %%
E=NetSalary()

# %%
E.get_details()
# Out:
# Enter Emplyoee ID:1
# Enter Emplyoee Name:john
# Enter Emplyoee Basic Salary:20000

# %%
E.Calculate()

# %%
E.cal_net_salary()

# %%
E.display1()
# Out:
# Emplyoee ID: 1
# Emplyoee Name: john
# Emplyoee Basic Salary: 20000
# DA: 7000.0
# HRA: 3400.0000000000005
# PF: 2400.0
# Total Addition 8000.0
# Total salary= 21000.0

# %% [markdown]
# Write a python program to create a Bus child class that inherits from the Vehicle class.
#  In Vehicle class vehicle name, mileage and seatingcapacity as its data member. The default fare charge of any vehicle is
# seating capacity * 100. If Vehicle is Bus instance, we need to add an extra 10% on full fare as a maintenance charge. So
# total fare for bus instance will become the final amount = total fare + 10% of the total fare.
#  Sample Output:
#  The bus seating capacity is 50. so, the final fare amount should be 5000+500=5500.
#  The car seating capacity is 5. so, the final fare amount should be 500.

# %%
class Vehicle:
    def __init__(self, name, mileage, seating_capacity):
        self.name = name
        self.mileage = mileage
        self.seating_capacity = seating_capacity
    def fare(self):
        return self.seating_capacity * 100
class Bus(Vehicle):
    def fare(self):
        base_fare = super().fare()
        maintenance = base_fare * 0.10
        return base_fare + maintenance

# %%
bus = Bus("School Bus", 12, 50)
print(f"Bus fare: {bus.fare()}")
car = Vehicle("Sedan", 25, 5)
print(f"Car fare: {car.fare()}")
print()
# Out:
# Bus fare: 5500.0
# Car fare: 500
